# %% [markdown]
# # 8. Ανάγνωση αρχείων csv, η βιβλιοθήκη pandas

# %% [markdown]
# Στόχος του μαθήματος είναι να εξοικειωθεί ο φοιτητής με την ανάγνωση και εγγραφή αρχείων CSV.
# Επίσης γίνεται μια σύντομη αναφορά στις δυνατότητες της βιβλιοθήκης pandas όσον αφορά την διαχείριση δεδομένων σε μορφή πινάκων.

# %% [markdown]
# ## Ανάγνωση αρχείων csv

# %% [markdown]
# Εισάγουμε τα απαραίτητα άρθρωματα (modules).

# %%
import os # μας επιτρέπει να έχουμε αλληλεπίδραση με το λειτουργικό σύστημα
import csv # απαραίτητο για την ανάγνωση και εγγραφή αρχείων CSV
from urllib import request # απαραίτητο για την λήψη αρχείων από το διαδίκτυο
import pandas as pd # η βιβλιοθήκη pandas για την διαχείρηση πινάκων
from pathlib import Path # βιβλιοθήκη για την διαχείριση των διαδρομών (paths) στον δίσκο
import numpy as np

# %% [markdown]
# Προαιρετικά ελέγχουμε ποιος είναι ο τρέχων κατάλογος:

# %%
print(os.getcwd())

# %% [markdown]
# Αρχικά κατεβάζουμε από το διαδίκτυο τα αναγκαία αρχεία CSV.
#
# (Πηγή δεδομένων https://www.kaggle.com/datasets/rinichristy/covid19-coronavirus-pandemic)

# %%
# Πρώτο αρχείο
remote_url = 'https://raw.githubusercontent.com/kokkytos/programming/main/docs/COVID-19%20Coronavirus.csv'
# Define the local filename to save data
local_file1 = 'COVID-19_Coronavirus.csv'
# Download remote and save locally
request.urlretrieve(remote_url, local_file1)

# Δεύτερο αρχείο
remote_url = 'https://raw.githubusercontent.com/kokkytos/programming/main/docs/COVID-19%20Coronavirus_V2.csv'
# Define the local filename to save data
local_file2 = 'COVID-19_Coronavirus_V2.csv'
# Download remote and save locally
request.urlretrieve(remote_url, local_file2)

# %%
with open(local_file1, 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)

# %%
with open(local_file1, 'r') as file:
    reader = csv.reader(file)
    line_count = 0
    for row in reader:
        if line_count == 0:
            print(f'Ονόματα στηλών {", ".join(row)}')
            print("\n\n")
            line_count += 1
        else:
            print(row)

# %% [markdown]
# To κόμμα (,) χρησιμοποιείται ως προκαθορισμένη επιλογή σαν διαχωριστικό στηλών.
# Μπορούμε ρητά να δηλώσουμε ποιο θα είναι το διαχωριστικό με την επιλογή _delimiter_.

# %%
with open(local_file2, 'r') as file:
    reader = csv.reader(file, delimiter = ';',quoting=csv.QUOTE_ALL)
    for row in reader:
        print(row)

# %%
with open(local_file1, 'r') as file:
    csv_file = csv.DictReader(file)
    for row in csv_file:
        print(dict(row))

# %%
with open(local_file1, 'r') as file:
    reader = csv.reader(file, delimiter = ';',quoting=csv.QUOTE_ALL)
    for row in reader:
        print(row)

# %% [markdown]
# ## Εγγραφή σε csv

# %%
with open('employee_file.csv', mode='w') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=';', quotechar='"', quoting=csv.QUOTE_ALL)

    employee_writer.writerow(['John Smith', 'Accounting', 'June'])
    employee_writer.writerow(['Erica Meyers', 'IT', 'March'])

# %% [markdown]
# Εγγραφή σε CSV από dictionary (λεξικό). Σε αυτή την περίπτωση πρέπει να ορίσουμε προκαταβολικά τα ονόματα των στηλών (fieldnames παράμετρος στην μέθοδο DictWriter) για να γίνει η ταυτοποίηση των κλειδιών από το λεξικό κατά την εγγραφή.

# %%
with open('employee_file2.csv', mode='w') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames= ['emp_name', 'dept', 'birth_month'],delimiter=';')

    writer.writeheader()
    writer.writerow({'emp_name': 'John Smith', 'dept': 'Accounting', 'birth_month': 'November'})
    writer.writerow({'emp_name': 'Erica Meyers', 'dept': 'IT', 'birth_month': 'March'})

# %% [markdown]
# ## Η βιβλιοθήκη pandas

# %% [markdown]
# ![alt text](pandas-data-structure.svg)

# %% [markdown]
# Δημιουργία pandas Series object

# %%
s = pd.Series([2, 4, 6, 8, 10])

# %% [markdown]
# Δημιουργία pandas Dataframe object. Η τελευτάι στήλη είναι από το προηγούμενο Series object.

# %%
df = pd.DataFrame({'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83], 'V':s});
df
# Out:
#     X   Y   Z   V
# 0  78  84  86   2
# 1  85  94  97   4
# 2  96  89  96   6
# 3  80  83  72   8
# 4  86  86  83  10

# %% [markdown]
# Δημιουργία Index object

# %%
index = pd.Index(list('abcde'))
print(index)
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %% [markdown]
# Αλλαγή Index σε ένα dataframe

# %%
df = df.set_index(index)
df
# Out:
#     X   Y   Z   V
# a  78  84  86   2
# b  85  94  97   4
# c  96  89  96   6
# d  80  83  72   8
# e  86  86  83  10

# %% [markdown]
# Επιλογή στηλών από το dataframe df σε ένα νέο dataframe με το όνομα df_subset

# %%
df_subset = df[['X','V']]
df_subset
# Out:
#     X   V
# a  78   2
# b  85   4
# c  96   6
# d  80   8
# e  86  10

# %% [markdown]
# Ορισμός τιμών μια στήλης σε κενό (nan), με βάση κριτήρια

# %%
df.loc[df['Z'] >= 96,'Z'] = np.nan
df
# Out:
#     X   Y     Z   V
# a  78  84  86.0   2
# b  85  94   NaN   4
# c  96  89   NaN   6
# d  80  83  72.0   8
# e  86  86  83.0  10

# %% [markdown]
# Φιλτράρισμα δεδομένων

# %%
df_2 =  df[df['V'] >= 6] 
df_2
# Out:
#     X   Y     Z   V
# c  96  89   NaN   6
# d  80  83  72.0   8
# e  86  86  83.0  10

# %% [markdown]
# ή αλλιώς:

# %%
df_2 =  df.loc[df['V'] >= 8] 
df_2
# Out:
#     X   Y     Z   V
# d  80  83  72.0   8
# e  86  86  83.0  10

# %% [markdown]
# με βάση συνθήκη όπου περιέχονται στην στήλη V τα στοιχεία της λίστας options

# %%
options=[4,10]
rslt_df = df[df['V'].isin(options)] 
rslt_df
# Out:
#     X   Y     Z   V
# b  85  94   NaN   4
# e  86  86  83.0  10

# %% [markdown]
# Τροποποίηση κελιού

# %%
df.at['a', 'V'] = 1000
df
# Out:
#     X   Y     Z     V
# a  78  84  86.0  1000
# b  85  94   NaN     4
# c  96  89   NaN     6
# d  80  83  72.0     8
# e  86  86  83.0    10

# %%
df.to_csv("leonidas.csv", sep=';', index=False)

# %% [markdown]
# Προσθήκη γραμμής

# %%
# Νεα γραμμή σαν dataframe

row_df = pd.DataFrame([ pd.Series([1,2,8,99])], index = ["f"])
row_df.columns =['X', 'Y', 'Z', 'V']
row_df
# Out:
#    X  Y  Z   V
# f  1  2  8  99

# %% [markdown]
# Εναλλακτικά φτιάχνουμε αν θελουμε την ιδια γραμμή με άλλη μέθοδο (μέσω ενός dictionary):

# %%
my_dictionary = {'X': [1], 'Y': [2],'Z': [8], 'V': [99]}
row_df = pd.DataFrame.from_dict(my_dictionary)
row_df = row_df.set_index(pd.Index(['f']))
row_df
# Out:
#    X  Y  Z   V
# f  1  2  8  99

# %%
# Συννένωση
df1 = pd.concat([df,row_df],ignore_index=False)
df1
# Out:
#     X   Y     Z     V
# a  78  84  86.0  1000
# b  85  94   NaN     4
# c  96  89   NaN     6
# d  80  83  72.0     8
# e  86  86  83.0    10
# f   1   2   8.0    99

# %% [markdown]
# Αντιμετάθεση στηλών και γραμμών (transpose)

# %%
df2 = df1.T # transpose
df2
# Out:
#         a     b     c     d     e     f
# X    78.0  85.0  96.0  80.0  86.0   1.0
# Y    84.0  94.0  89.0  83.0  86.0   2.0
# Z    86.0   NaN   NaN  72.0  83.0   8.0
# V  1000.0   4.0   6.0   8.0  10.0  99.0

# %%
list(df2.columns)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
list(df1.index)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %% [markdown]
# Μπορούμε να διαβάσουμε ένα αρχείο CSV σαν pandas dataframe.
#
# Ακολουθεί το παρακάτω παράδειγμα με δεδομένα Airbnb.
#
# Λήψη αρχείου csv από το διαδίκτυο:

# %%
remote_url = 'http://data.insideairbnb.com/greece/attica/athens/2021-12-23/visualisations/listings.csv'
# Define the local filename to save data
local_file3 = 'listings.csv'
# Download remote and save locally
request.urlretrieve(remote_url, local_file3)
# Out:
# ('listings.csv', <http.client.HTTPMessage at 0x7fdc3c8dde70>)

# %% [markdown]
# Ανάγνωση του αρχείου σαν panda DataFrame

# %%
# read the airbnb NYC listings csv file
airbnb = pd.read_csv(local_file3)

# %% [markdown]
# Εκτύπωση των πρώτων 10 γραμμών

# %%
airbnb.head()
# Out:
#       id                                            name  host_id  host_name  \
# 0  10595             96m2, 3BR, 2BA, Metro, WI-FI etc...    37177  Emmanouil
# 1  10990    Athens Quality Apartments - Deluxe Apartment    37177  Emmanouil
# 2  10993              Athens Quality Apartments - Studio    37177  Emmanouil
# 3  10995  AQA-No2 1-bedroom, smart tv, fiber connection,    37177  Emmanouil
# 4  27262              54m2, 1-br, cable tv, wi-fi, metro    37177  Emmanouil
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98863   23.76527  Entire home/apt
# 1                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98903   23.76448  Entire home/apt
# 2                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98888   23.76473  Entire home/apt
# 3                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98903   23.76448  Entire home/apt
# 4                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98924   23.76500  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0     70               1                 32  2021-09-24               0.25
# 1     50               1                 54  2021-11-01               0.48
# 2     38               1                 76  2021-12-09               0.67
# 3     48               1                 27  2021-11-08               0.19
# 4     52               1                 17  2020-01-08               0.15
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               6               114                      7
# 1                               6               364                     10
# 2                               6               312                     22
# 3                               6               236                      4
# 4                               6               176                      0
#
#        license
# 0  00000957568
# 1  00001070920
# 2  00000957080
# 3  00000957422
# 4  00000957579

# %% [markdown]
# Εκτύπωση των 5 τελευταίων γραμμών

# %%
airbnb.tail(10)
# Out:
#             id                                               name    host_id  \
# 9663  53913979              Beautiful Apt. closed to Monastiraki!   35760684
# 9664  53914527                 Cosy duplex apartment at Petralona  195674383
# 9665  53914614  Classical vibes in this deluxe apt. in heart o...   35760684
# 9666  53915110   Family Room at the Trendy by Athens Prime Hotels  436756020
# 9667  53916052  Modern, stylish and big apartment in Athens ce...  436763650
# 9668  53928165                                   About love AT015  428201678
# 9669  53930376           Superior Queen Room by 33 Solonos suites  114156592
# 9670  53932240  2 room sunny modern apartment, top floor + bal...   34801484
# 9671  53934984  Διαμέρισμα στην πλατεία Αττικής ,πλησίον του μ...  381802767
# 9672  53938913                                         A.P Athens  423806621
#
#         host_name  neighbourhood_group                     neighbourhood  \
# 9663        Eleni                  NaN                        ΚΕΡΑΜΕΙΚΟΣ
# 9664        Selda                  NaN                         ΠΕΤΡΑΛΩΝΑ
# 9665        Eleni                  NaN                        ΚΕΡΑΜΕΙΚΟΣ
# 9666        Paris                  NaN            ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ
# 9667     Styliani                  NaN  ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ
# 9668      Fenglin                  NaN  ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ
# 9669  Bill & John                  NaN                          ΚΟΛΩΝΑΚΙ
# 9670        Daria                  NaN  ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ
# 9671        Hakob                  NaN                   ΣΤΑΘΜΟΣ ΛΑΡΙΣΗΣ
# 9672         Anna                  NaN                        ΝΕΑ ΚΥΨΕΛΗ
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 9663  37.980058  23.719821  Entire home/apt     90               2
# 9664  37.974262  23.709322  Entire home/apt     48               3
# 9665  37.980330  23.721530  Entire home/apt     90               2
# 9666  37.985432  23.732206     Private room    143               1
# 9667  37.984031  23.721455  Entire home/apt     70               2
# 9668  37.991477  23.723229  Entire home/apt     40               2
# 9669  37.979829  23.736844     Private room    110               1
# 9670  37.982810  23.718970  Entire home/apt     33               4
# 9671  37.997002  23.720508  Entire home/apt     32               1
# 9672  37.996459  23.744231  Entire home/apt     40               1
#
#       number_of_reviews last_review  reviews_per_month  \
# 9663                  0         NaN                NaN
# 9664                  0         NaN                NaN
# 9665                  0         NaN                NaN
# 9666                  0         NaN                NaN
# 9667                  0         NaN                NaN
# 9668                  0         NaN                NaN
# 9669                  0         NaN                NaN
# 9670                  0         NaN                NaN
# 9671                  0         NaN                NaN
# 9672                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 9663                               5               360                      0
# 9664                               1               354                      0
# 9665                               5               360                      0
# 9666                               1               324                      0
# 9667                               1               364                      0
# 9668                               2               167                      0
# 9669                              32               365                      0
# 9670                               1               276                      0
# 9671                               1               365                      0
# 9672                               1               365                      0
#
#           license
# 9663  88749558874
# 9664       Exempt
# 9665  33332541105
# 9666      1190373
# 9667  00001393010
# 9668  00001372314
# 9669  00001393195
# 9670       Exempt
# 9671       Exempt
# 9672  00001396920

# %% [markdown]
# Μπορούμε να πάρουμε για όλες τις αριθμητικές στήλες περιγραφικά στατιστικά (mean, std, min, τεταρτημόρια κτλ) με την μέθοδο describe()

# %%
airbnb.describe()
# Out:
#                  id       host_id  neighbourhood_group     latitude  \
# count  9.673000e+03  9.673000e+03                  0.0  9673.000000
# mean   3.255635e+07  1.475417e+08                  NaN    37.979912
# std    1.366145e+07  1.188964e+08                  NaN     0.013241
# min    1.059500e+04  3.717700e+04                  NaN    37.950550
# 25%    2.293145e+07  3.904215e+07                  NaN    37.969230
# 50%    3.335690e+07  1.304658e+08                  NaN    37.978340
# 75%    4.377216e+07  2.284115e+08                  NaN    37.987960
# max    5.393891e+07  4.367636e+08                  NaN    38.034497
#
#          longitude        price  minimum_nights  number_of_reviews  \
# count  9673.000000  9673.000000     9673.000000        9673.000000
# mean     23.731762    86.912850        3.234570          42.868913
# std       0.012369   326.785191       19.523021          71.038260
# min      23.697700     7.000000        1.000000           0.000000
# 25%      23.723970    36.000000        1.000000           1.000000
# 50%      23.729810    50.000000        2.000000          13.000000
# 75%      23.737820    80.000000        2.000000          52.000000
# max      23.780220  8000.000000     1000.000000         753.000000
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# count        7916.000000                     9673.000000       9673.000000
# mean            1.520586                       10.923292        240.921638
# std             1.590922                       22.798110        127.491219
# min             0.010000                        1.000000          0.000000
# 25%             0.350000                        1.000000        151.000000
# 50%             1.000000                        3.000000        296.000000
# 75%             2.172500                        9.000000        353.000000
# max            20.390000                      153.000000        365.000000
#
#        number_of_reviews_ltm
# count            9673.000000
# mean                9.771632
# std                15.926126
# min                 0.000000
# 25%                 0.000000
# 50%                 3.000000
# 75%                13.000000
# max               359.000000

# %% [markdown]
# Ανάγνωση των δεδομένων μιας στήλης σαν pandas Series

# %%
# Results for a single column
airbnb['name']
# Out:
# 0                     96m2, 3BR, 2BA, Metro, WI-FI etc...
# 1            Athens Quality Apartments - Deluxe Apartment
# 2                      Athens Quality Apartments - Studio
# 3          AQA-No2 1-bedroom, smart tv, fiber connection,
# 4                      54m2, 1-br, cable tv, wi-fi, metro
#                               ...
# 9668                                     About love AT015
# 9669             Superior Queen Room by 33 Solonos suites
# 9670    2 room sunny modern apartment, top floor + bal...
# 9671    Διαμέρισμα στην πλατεία Αττικής ,πλησίον του μ...
# 9672                                           A.P Athens
# Name: name, Length: 9673, dtype: object

# %% [markdown]
# Επιλογή συγκεκριμένων στηλών από το dataframe

# %%
# results for multiple columns
airbnb[['host_id', 'host_name']]
# Out:
#         host_id    host_name
# 0         37177    Emmanouil
# 1         37177    Emmanouil
# 2         37177    Emmanouil
# 3         37177    Emmanouil
# 4         37177    Emmanouil
# ...         ...          ...
# 9668  428201678      Fenglin
# 9669  114156592  Bill & John
# 9670   34801484        Daria
# 9671  381802767        Hakob
# 9672  423806621         Anna
#
# [9673 rows x 2 columns]

# %% [markdown]
# Επιστροφή του τύπου δεδομένων για όλες τις στήλες

# %%
airbnb.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %% [markdown]
# Μετατροπή της στήλης last_review σε datetime64 object

# %%
airbnb['last_review'] = pd.to_datetime(airbnb['last_review'])
airbnb.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                      float64
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# license                                   object
# dtype: object

# %% [markdown]
# Μπορούμε να εξάγουμε το έτος από ένα datetime object σε μια νέα στήλη. Μετατροπή της στήλης year σε ακέραιο

# %%
# extract the year from a datetime series
airbnb['year'] = airbnb['last_review'].dt.year

# to integer
airbnb['year'] = airbnb['year'].astype('UInt16')

airbnb['year'].head()
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2020
# Name: year, dtype: UInt16

# %% [markdown]
# Το ίδιο μπορούμε να κάνουμε και με τον μήνα.

# %%
airbnb['month'] = airbnb['last_review'].dt.month
airbnb['month']=airbnb['month'].astype('UInt16')
airbnb.head()
# Out:
#       id                                            name  host_id  host_name  \
# 0  10595             96m2, 3BR, 2BA, Metro, WI-FI etc...    37177  Emmanouil
# 1  10990    Athens Quality Apartments - Deluxe Apartment    37177  Emmanouil
# 2  10993              Athens Quality Apartments - Studio    37177  Emmanouil
# 3  10995  AQA-No2 1-bedroom, smart tv, fiber connection,    37177  Emmanouil
# 4  27262              54m2, 1-br, cable tv, wi-fi, metro    37177  Emmanouil
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98863   23.76527  Entire home/apt
# 1                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98903   23.76448  Entire home/apt
# 2                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98888   23.76473  Entire home/apt
# 3                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98903   23.76448  Entire home/apt
# 4                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98924   23.76500  Entire home/apt
#
#    price  ...  number_of_reviews  last_review reviews_per_month  \
# 0     70  ...                 32   2021-09-24              0.25
# 1     50  ...                 54   2021-11-01              0.48
# 2     38  ...                 76   2021-12-09              0.67
# 3     48  ...                 27   2021-11-08              0.19
# 4     52  ...                 17   2020-01-08              0.15
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               6               114                      7
# 1                               6               364                     10
# 2                               6               312                     22
# 3                               6               236                      4
# 4                               6               176                      0
#
#        license  year  month  day
# 0  00000957568  2021      9   24
# 1  00001070920  2021     11    1
# 2  00000957080  2021     12    9
# 3  00000957422  2021     11    8
# 4  00000957579  2020      1    8
#
# [5 rows x 21 columns]

# %% [markdown]
# Αν κάποια στήλη περιέχει κενά στην αρχή ή το τέλος της μπορούμε να τα αφαιρέσουμε ως εξής:

# %%
airbnb['name'] = airbnb['name'].str.strip()
airbnb['name'].head()
# Out:
# 0               96m2, 3BR, 2BA, Metro, WI-FI etc...
# 1      Athens Quality Apartments - Deluxe Apartment
# 2                Athens Quality Apartments - Studio
# 3    AQA-No2 1-bedroom, smart tv, fiber connection,
# 4                54m2, 1-br, cable tv, wi-fi, metro
# Name: name, dtype: object

# %% [markdown]
# Μετατροπή όλων των χαρακτήρων μιας στήλης σε πεζά:

# %%
airbnb['name_lower'] = airbnb['name'].str.lower()
airbnb['name_lower'].head()
# Out:
# 0               96m2, 3br, 2ba, metro, wi-fi etc...
# 1      athens quality apartments - deluxe apartment
# 2                athens quality apartments - studio
# 3    aqa-no2 1-bedroom, smart tv, fiber connection,
# 4                54m2, 1-br, cable tv, wi-fi, metro
# Name: name_lower, dtype: object

# %% [markdown]
# Δημιουργία μιας στήλης που στηρίζεται σε υπολογισμό μεταξύ άλλων στηλών (calculated column)

# %%
airbnb['min_revenue'] = airbnb['minimum_nights'] * airbnb['price']
airbnb[['minimum_nights', 'price', 'min_revenue']]
# Out:
#       minimum_nights  price  min_revenue
# 0                  1     70           70
# 1                  1     50           50
# 2                  1     38           38
# 3                  1     48           48
# 4                  1     52           52
# ...              ...    ...          ...
# 9668               2     40           80
# 9669               1    110          110
# 9670               4     33          132
# 9671               1     32           32
# 9672               1     40           40
#
# [9673 rows x 3 columns]

# %% [markdown]
# Υπολογισμός του μέσου όρου μιας στήλης

# %%
airbnb['price'].mean()
# Out:
# 86.91285020159206

# %% [markdown]
# Υπολογισμός του διαμέσου μιας στήλης

# %%
airbnb['price'].median()
# Out:
# 50.0

# %% [markdown]
# Υπολογισμό μέσου όρου τιμής ανά τύπο δωματίου

# %%
airbnb[['room_type', 'price']].groupby('room_type', as_index=False).mean()
# Out:
#          room_type       price
# 0  Entire home/apt   84.221882
# 1       Hotel room  188.514706
# 2     Private room  100.025054
# 3      Shared room   61.857143

# %% [markdown]
# Υπολογισμό διαμέσου τιμής ανά τύπο δωματίου. Χρησιμοποιούμε την στήλη room_type σαν index

# %%
airbnb[['room_type', 'price']].groupby('room_type', as_index=True).median()
# Out:
#                  price
# room_type
# Entire home/apt   51.0
# Hotel room       105.0
# Private room      38.0
# Shared room       14.0

# %% [markdown]
# Υπολογισμό διαμέσου τιμής ανά τύπο δωματίου και έτος

# %%
airbnb[['room_type', 'year', 'price']].groupby(['room_type', 'year'], as_index=False).mean()
# Out:
#           room_type  year       price
# 0   Entire home/apt  2013  133.000000
# 1   Entire home/apt  2014   89.666667
# 2   Entire home/apt  2015   63.500000
# 3   Entire home/apt  2016   90.432432
# 4   Entire home/apt  2017   92.000000
# 5   Entire home/apt  2018   90.602094
# 6   Entire home/apt  2019  111.112040
# 7   Entire home/apt  2020   74.048780
# 8   Entire home/apt  2021   69.686602
# 9        Hotel room  2017  116.333333
# 10       Hotel room  2018   96.800000
# 11       Hotel room  2019  610.882353
# 12       Hotel room  2020  115.600000
# 13       Hotel room  2021  108.051282
# 14     Private room  2015  160.000000
# 15     Private room  2016   51.285714
# 16     Private room  2017   67.000000
# 17     Private room  2018   55.966667
# 18     Private room  2019   53.809524
# 19     Private room  2020  124.762712
# 20     Private room  2021   43.755376
# 21      Shared room  2017   42.000000
# 22      Shared room  2019  257.500000
# 23      Shared room  2020  391.666667
# 24      Shared room  2021   12.952381

# %% [markdown]
# Φιλτράρισμα γραμμών με βάση ένα κριτήριο (τιμή <1000) και προσάρτηση σε ένα νέο dataframe

# %%
# get all rows with price < 1000
airbnb_under_1000 = airbnb[airbnb['price'] < 1000]
airbnb_under_1000.head()
# Out:
#       id                                            name  host_id  host_name  \
# 0  10595             96m2, 3BR, 2BA, Metro, WI-FI etc...    37177  Emmanouil
# 1  10990    Athens Quality Apartments - Deluxe Apartment    37177  Emmanouil
# 2  10993              Athens Quality Apartments - Studio    37177  Emmanouil
# 3  10995  AQA-No2 1-bedroom, smart tv, fiber connection,    37177  Emmanouil
# 4  27262              54m2, 1-br, cable tv, wi-fi, metro    37177  Emmanouil
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98863   23.76527  Entire home/apt
# 1                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98903   23.76448  Entire home/apt
# 2                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98888   23.76473  Entire home/apt
# 3                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98903   23.76448  Entire home/apt
# 4                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98924   23.76500  Entire home/apt
#
#    price  ...  reviews_per_month  calculated_host_listings_count  \
# 0     70  ...               0.25                               6
# 1     50  ...               0.48                               6
# 2     38  ...               0.67                               6
# 3     48  ...               0.19                               6
# 4     52  ...               0.15                               6
#
#   availability_365  number_of_reviews_ltm      license  year  month day  \
# 0              114                      7  00000957568  2021      9  24
# 1              364                     10  00001070920  2021     11   1
# 2              312                     22  00000957080  2021     12   9
# 3              236                      4  00000957422  2021     11   8
# 4              176                      0  00000957579  2020      1   8
#
#                                        name_lower  min_revenue
# 0             96m2, 3br, 2ba, metro, wi-fi etc...           70
# 1    athens quality apartments - deluxe apartment           50
# 2              athens quality apartments - studio           38
# 3  aqa-no2 1-bedroom, smart tv, fiber connection,           48
# 4              54m2, 1-br, cable tv, wi-fi, metro           52
#
# [5 rows x 23 columns]

# %% [markdown]
# Φιλτράρισμα με πολλαπλά κριτήρια (τιμή <1000 και έτος 2020)

# %%
# get all rows with price < 1000 and year equal to 2020
airbnb_2019_under_1000 = airbnb[(airbnb['price'] < 1000) & (airbnb['year'] == 2020)]
airbnb_2019_under_1000.head()
# Out:
#         id                                      name  host_id       host_name  \
# 4    27262        54m2, 1-br, cable tv, wi-fi, metro    37177       Emmanouil
# 18  138386       Apartment Dora , Service with style   675611           Yavor
# 30  281158          Center 1, Metro 30m, Satelite TV   640163           Nikos
# 41  469140  Our first love #01 | Thiseio Residencies  2289590  Live In Athens
# 42  470219  Our Playground #02 | Thiseio Residencies  2289590  Live In Athens
#
#     neighbourhood_group    neighbourhood  latitude  longitude  \
# 4                   NaN      ΑΜΠΕΛΟΚΗΠΟΙ  37.98924   23.76500
# 18                  NaN         ΠΑΓΚΡΑΤΙ  37.96783   23.74970
# 30                  NaN  ΠΛΑΤΕΙΑ ΑΤΤΙΚΗΣ  37.99253   23.73115
# 41                  NaN           ΘΗΣΕΙΟ  37.97665   23.71850
# 42                  NaN           ΘΗΣΕΙΟ  37.97525   23.71957
#
#           room_type  price  ...  reviews_per_month  \
# 4   Entire home/apt     52  ...               0.15
# 18  Entire home/apt     58  ...               0.47
# 30  Entire home/apt     45  ...               0.48
# 41  Entire home/apt     89  ...               0.51
# 42  Entire home/apt     64  ...               0.15
#
#     calculated_host_listings_count availability_365  number_of_reviews_ltm  \
# 4                                6              176                      0
# 18                               1               52                      0
# 30                               9              144                      0
# 41                              13              301                      0
# 42                              13              251                      0
#
#         license  year  month day                                name_lower  \
# 4   00000957579  2020      1   8        54m2, 1-br, cable tv, wi-fi, metro
# 18  00000208960  2020      1  20       apartment dora , service with style
# 30  00000251837  2020      2  29          center 1, metro 30m, satelite tv
# 41  00000546911  2020     11   2  our first love #01 | thiseio residencies
# 42  00001176980  2020     10  12  our playground #02 | thiseio residencies
#
#     min_revenue
# 4            52
# 18          174
# 30           90
# 41          178
# 42        64000
#
# [5 rows x 23 columns]

# %% [markdown]
# Ιστόγραμμα για την στήλη price στον πίνακα airbnb_under_1000

# %%
ax = airbnb_under_1000['price'].plot.hist(bins=40)

# %% [markdown]
# ## Βιβλιογραφία
#
# pandas Tutorial for Beginners, https://www.datacamp.com/tutorial/pandas, Πρόσβαση: 18/05/2022
#
# Reading and Writing CSV Files in Python, https://realpython.com/python-csv/#reading-csv-files-with-csv, Πρόσβαση: 18/05/2022
#
# Reading CSV files in Python, https://www.programiz.com/python-programming/reading-csv-files, Πρόσβαση: 18/05/2022
#
# COVID-19 Coronavirus Pandemic, https://www.kaggle.com/datasets/rinichristy/covid19-coronavirus-pandemic, Πρόσβαση: 18/05/2022
# Pandas User Guide, https://pandas.pydata.org/docs/user_guide/index.html#user-guide, Πρόσβαση: 23/05/2022
#
# McKinney, W., 2013. Python for data analysis. O’Reilly, Beijing.
